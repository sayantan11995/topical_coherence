# %%
import json
import networkx as nx
import operator
import pickle
import os, os.path
import fnmatch
import nltk
# Out:
# C:\ProgramData\Anaconda3_new\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3_new\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3_new\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
with open('config.json') as handle:
    config = json.load(handle)
book = config['book_name']
Parts = config['number_of_parts']
window_size = config['temporal_window_size']

# %%
with open('json_files/%s/date_place_list.json' % book) as handle:
    date_place_list = json.load(handle)

with open('json_files/%s/date_person_list.json' %book) as handle:
    date_person_list= json.load(handle)

# %%
ent_date = {'places':{},'people':{}}
for date in date_person_list:
    if date in ent_date['people']:
        ent_date['people'][date].extend(date_person_list[date])
    else:
        ent_date['people'][date] = date_person_list[date]

for date in date_place_list:
    if date in ent_date['places']:
        ent_date['places'][date].extend(date_place_list[date])
    else:
        ent_date['places'][date] = date_place_list[date]
ent_date
# Out:
# {'places': {'1857': ['Delhi',
#    'Arabia',
#    'Turkey',
#    'Ajmer',
#    'Spain',
#    'England',
#    'Kabul',
#    'Afghanistan',
#    'Aligarh',
#    'Lucknow',
#    'Egypt',
#    'France',
#    'Persia',
#    'Agra',
#    'Western',
#    'London',
#    'Allahabad'],
#   '1930': ['Poona',
#    'England',
#    'Japan',
#    'Independence',
#    'Raipur',
#    'Moscow',
#    'Cambridge',
#    'Salt',
#    'New York',
#    'Ahmedabad',
#    'Simla',
#    'North',
#    'Australia',
#    'Spain',
#    'Lahore',
#    'France',
#    'Italy',
#    'America',
#    'Zenda',
#    'Singapore',
#    'Paris',
#    'Batavia',
#    'Allahabad',
#    'Union',
#    'Russia',
#    'Kabul',
#    'Lucknow',
#    'Gujrat',
#    'Harrow',
#    'Peshawar',
#    'London',
#    'Karachi',
#    'Delhi',
#    'Kars',
#    'Madras',
#    'Persia',
#    'Germany',
#    'China',
#    'Meerut'],
#   '1907': ['Tsushima',
#    'Ireland',
#    'Geneva',
#    'Dover',
#    'Baroda',
#    'Poona',
#    'England',
#    'Surat',
#    'Berlin',
#    'France',
#    'Norway',
#    'Italy',
#    'Harrow',
#    'Cambridge',
#    'Western',
#    'Paris',
#    'London',
#    'Allahabad'],
#   '1916': ['Ireland',
#    'Delhi',
#    'Simla',
#    'England',
#    'Fiji',
#    'Lucknow',
#    'France',
#    'New Delhi',
#    'Empire',
#    'Germany',
#    'South Africa',
#    'London',
#    'Allahabad'],
#   '1919': ['Ahmedabad', 'Turkey', 'Delhi', 'Lahore', 'Amritsar', 'Allahabad'],
#   '1920': ['Ahmedabad',
#    'Karachi',
#    'Fyzabad',
#    'Simla',
#    'Fiji',
#    'Afghanistan',
#    'Lucknow',
#    'Gujrat',
#    'Agra',
#    'Allahabad'],
#   '1939': ['Glasgow',
#    'Geneva',
#    'Delhi',
#    'Bray',
#    'Fyzabad',
#    'Union',
#    'England',
#    'Akbarpur',
#    'Nagpur',
#    'Jamshedpur',
#    'Lucknow',
#    'Madras',
#    'Independence',
#    'America',
#    'Dundee',
#    'Meerut',
#    'Allahabad'],
#   '1921': ['North',
#    'Nagpur',
#    'Lucknow',
#    'Independence',
#    'America',
#    'Amritsar',
#    'South Africa',
#    'Empire',
#    'Meerut',
#    'Allahabad'],
#   '1932': ['Delhi', 'Young', 'England', 'New Delhi', 'London', 'Allahabad'],
#   '1933': ['Canterbury',
#    'Jaito',
#    'Poona',
#    'England',
#    'Istanbul',
#    'Japan',
#    'Moscow',
#    'Ambala',
#    'Hampstead',
#    'Cambridge',
#    'Agra',
#    'Switzerland',
#    'New York',
#    'Montana',
#    'Geneva',
#    'Simla',
#    'North',
#    'San Francisco',
#    'Nagpur',
#    'Afghanistan',
#    'Berlin',
#    'France',
#    'Italy',
#    'America',
#    'Latvia',
#    'Empire',
#    'Lithuania',
#    'Paris',
#    'Allahabad',
#    'Ireland',
#    'Union',
#    'Russia',
#    'Sweden',
#    'Lucknow',
#    'Gujrat',
#    'Harrow',
#    'Amritsar',
#    'Patiala',
#    'London',
#    'Delhi',
#    'Madras',
#    'Almora',
#    'Western',
#    'Germany',
#    'China'],
#   '1924': ['Ahmedabad',
#    'Delhi',
#    'Dalhousie',
#    'North',
#    'Poona',
#    'Young',
#    'Lahore',
#    'Belgaum',
#    'Italy',
#    'Empire',
#    'London',
#    'Allahabad'],
#   '1925': ['Venice', 'Switzerland', 'Lucknow', 'Allahabad'],
#   '1926': ['England',
#    'Moscow',
#    'Switzerland',
#    'Geneva',
#    'Brussels',
#    'Ahmedabad',
#    'Turkey',
#    'North',
#    'Venice',
#    'Berlin',
#    'France',
#    'Italy',
#    'America',
#    'Marseilles',
#    'Paris',
#    'Allahabad',
#    'Mexico',
#    'Russia',
#    'Kabul',
#    'Lucknow',
#    'Egypt',
#    'Palestine',
#    'London',
#    'Delhi',
#    'Cologne',
#    'Madras',
#    'Colombo',
#    'Germany',
#    'China'],
#   '1928': ['Delhi',
#    'Union',
#    'Russia',
#    'Lahore',
#    'Lucknow',
#    'Madras',
#    'Gujrat',
#    'Independence',
#    'New Delhi',
#    'America',
#    'Allahabad'],
#   '1929': ['Geneva',
#    'Delhi',
#    'Nagpur',
#    'Lahore',
#    'Lucknow',
#    'America',
#    'Amritsar',
#    'Gorakhpur',
#    'Meerut'],
#   '1931': ['Canterbury',
#    'Poona',
#    'England',
#    'New Delhi',
#    'Eden',
#    'Simla',
#    'Turkey',
#    'Empire',
#    'Chittagong',
#    'South Africa',
#    'Paris',
#    'Allahabad',
#    'Union',
#    'Kabul',
#    'Paradise',
#    'Lucknow',
#    'Rome',
#    'London',
#    'Karachi',
#    'Delhi',
#    'Madras',
#    'Western',
#    'Germany'],
#   '1937': ['Malabar',
#    'Travancore',
#    'Delhi',
#    'Cochin',
#    'Jerusalem',
#    'Mysore',
#    'Hyderabad',
#    'Antioch'],
#   '1858': ['Poona',
#    'England',
#    'Russia',
#    'Whitehall',
#    'Lucknow',
#    'Madras',
#    'Gujrat',
#    'Empire',
#    'Austria',
#    'Germany',
#    'Paris'],
#   '1934': ['Poona',
#    'England',
#    'Japan',
#    'Mysore',
#    'Independence',
#    'New Delhi',
#    'Howrah',
#    'Austria',
#    'Ahmedabad',
#    'Turkey',
#    'Simla',
#    'North',
#    'Australia',
#    'Spain',
#    'Muzaffarpur',
#    'Afghanistan',
#    'France',
#    'Italy',
#    'America',
#    'Empire',
#    'South Africa',
#    'Patna',
#    'Allahabad',
#    'Ireland',
#    'Cambrai',
#    'Rhine',
#    'Union',
#    'Russia',
#    'Jamalpur',
#    'Byron',
#    'Lucknow',
#    'Egypt',
#    'Rome',
#    'Canada',
#    'Boston',
#    'Whitehall',
#    'London',
#    'Karachi',
#    'Delhi',
#    'Calais',
#    'Aligarh',
#    'Madras',
#    'Deoli',
#    'Persia',
#    'Almora',
#    'Liberty',
#    'Gorakhpur',
#    'Western',
#    'Germany',
#    'Providence',
#    'Cairo'],
#   '1935': ['Travancore',
#    'Cochin',
#    'England',
#    'Japan',
#    'Mysore',
#    'Ahmedabad',
#    'Afghanistan',
#    'France',
#    'Hyderabad',
#    'South Africa',
#    'Ireland',
#    'Baroda',
#    'Union',
#    'Quetta',
#    'Gujrat',
#    'Patiala',
#    'London',
#    'Delhi',
#    'Madras',
#    'Almora',
#    'Western',
#    'Germany'],
#   '1913': ['Almora']},
#  'people': {'1857': ['Syed Ahmad Khan',
#    'Mudx',
#    'Minto',
#    'Madan Mohan Malaviya',
#    'Rabindranath',
#    'Valentine Chirol',
#    'Lord Lloyd',
#    'Agra Province',
#    'Nand Lai Nehru',
#    'Bahadur Sapru',
#    'Kemal Pasha',
#    'Farrukhsiar',
#    'Malaviyaji',
#    'Raj Kaul',
#    'Ram Lila',
#    'Tej',
#    'Muiishiji',
#    'Cowley',
#    'Amanullah',
#    'Aurungzeb',
#    'Munshi Mubarak Ali',
#    'Dhar',
#    'Lakshmi Narayan Nehru',
#    'Ansari'],
#   '1930': ['Chloe',
#    'Sardar Vallabhbhai Patel',
#    'Mahatma Gandhi',
#    'Bharat Bhushan',
#    'Jambusar',
#    'Indira',
#    'Olrott',
#    'Samuel Hoare',
#    'Ranjit Pandit',
#    'Blavatsky',
#    'Sardar VaUabhbhai Patel',
#    'Jumna',
#    'Annie Besant',
#    'Malcolm Hailey',
#    'Gustave Dora',
#    'Frederick Cooper',
#    'Gokhale',
#    'Jairamdas Doulatram',
#    'Abdul GhafFar Khan',
#    'Ibbetson',
#    'Swaraj',
#    'Lewis Carroll',
#    'Govind Ballabh Pant',
#    'Apollonius',
#    'Don Quixote',
#    'Lewis E. Lawes',
#    'Lafeadio Hearn',
#    'Eleven Points',
#    'Irwm',
#    'Bahadur Sapru',
#    'Sarojini Naidu',
#    'Garhwalis',
#    'Chandrashekhar Azad',
#    'Syed Mahmucl',
#    'Malaviyaji',
#    'Madeleine Slade',
#    'Jayakar',
#    'Queen Victoria',
#    'Narmada Prasad',
#    'Ramsay MacDonald',
#    'Chauri',
#    'Khudai Khidmatgar',
#    'Iwer',
#    'Motilal',
#    'Ranjit S. Pandit',
#    'Thomas Moore',
#    'Bhagat Singh',
#    'Marshal Foch',
#    'Srinivas Sastri',
#    'Kamala',
#    'Saprii',
#    'Qiauri Chaura',
#    'Khan Abdul Ghaffar Khan',
#    'Anand Bhawan',
#    'Tej',
#    'Syed Mahmud',
#    'Maulana Abul Kalam Azad',
#    'Ganeshji',
#    'Abdul Ghaffor Khan',
#    'Miraben',
#    'Bryce',
#    'Keith',
#    'Maulana Mohamad Ali',
#    'Jhanda',
#    'Redshirts',
#    'Kirkee',
#    'Deshbandhu Das'],
#   '1907': ['Latham',
#    'Khwaja',
#    'Edwin Montagu',
#    'Gokhale',
#    'Nevinson',
#    'Paramjit Singh',
#    'Walter Pater',
#    'Farman',
#    'Majlis',
#    'Sahab',
#    'Shyamji',
#    'Bepin Pal',
#    'Lalaji',
#    'Lala Lajpat Rai',
#    'Dayal',
#    'Syed Mahmud',
#    'Inis',
#    'Zeppdin',
#    'Otto Weininger',
#    'Ansari',
#    'Bernard Shaw'],
#   '1916': ['Mahatma Gandhi',
#    'Manasarovar',
#    'Srinivasa Sastri',
#    'Edwin Montagu',
#    'Minto',
#    'Madan Mohan Malaviya',
#    'Gokhale',
#    'Lokamanya Tilak',
#    'Basu',
#    'Bahadur Sapru',
#    'Matayan',
#    'Sarojini Naidu',
#    'Chelmsford',
#    'Bhupendra Nath Basy',
#    'Forster',
#    'Srinivas Sastri',
#    'Khaparde',
#    'Tej',
#    'Bertrand Russell',
#    'Amaranath'],
#   '1919': ['Lokamanya Tilak',
#    'Mahatma Gandhi',
#    'Shaukat Ali',
#    'Chelmsford',
#    'Swami Shraddhananda'],
#   '1920': ['Sardar Vallabbhai Patel',
#    'Richard B. Gregg',
#    'Hindt Ramayana',
#    'Wolseley',
#    'Amanullah',
#    'Dehra Dun',
#    'Richard Garnett',
#    'Ramacnandra',
#    'Wotton',
#    'Deshbandhu Das',
#    'Vithalbhai Patel',
#    'Reinhold',
#    'Baba Ramachandra',
#    'Jumna',
#    'Grimwood',
#    'Chelmsford',
#    'Ayodhya',
#    'Kamala'],
#   '1939': ['Swaraj', 'Ansari', 'Joshi', 'Mahatma Gandhi'],
#   '1921': ['Purushottam Das Tandon',
#    'Mahatma Gandhi',
#    'Indira',
#    'Srinivasa Sastri',
#    'Balkrishna Sharma',
#    'Rama Raj',
#    'Devadas Gandhi',
#    'Gokhale',
#    'Valentine Chirol',
#    'Lokamanya Tilak',
#    'Swaraj',
#    'Khan Bahadur',
#    'Walter Pater',
#    'Santiniketan',
#    'Sarojini Naidu',
#    'Maulanas',
#    'Lala LajpatRai',
#    'Mahadev Desai',
#    'Rabindra Nath Tagore',
#    'Motilal',
#    'Swarup',
#    'George Joseph',
#    'Lalaji',
#    'Anand Bhawan',
#    'Lala Lajpat Rai',
#    'Seeley',
#    'Deshbandhu Das'],
#   '1932': ['Mahatma Gandhi',
#    'Swaraj',
#    'Narmada Prasad',
#    'Samuel Hoare',
#    'Chauri',
#    'Bernard Aluvihare',
#    'Matthew Arnold',
#    'Irwm',
#    'Mohanlal Nehru',
#    'Banjit Pandit',
#    'Willingdon'],
#   '1933': ['Moonje',
#    'Voltairej',
#    'Indira',
#    'Dehra Dun',
#    'Rajagopalachariar',
#    'Srinivasa Sastri',
#    'Samuel Hoare',
#    'Ranjit Pandit',
#    'Barkatulla',
#    'Ernst Toller',
#    'Samamim',
#    'John Dewey',
#    'Sarup',
#    'Subhas Bose',
#    'Ritssia',
#    'Verrier Elwin',
#    'Champakraman Pillai',
#    'Remain Rolland',
#    'Roger Baldwin',
#    'Swaraj',
#    'Kapil',
#    'Chatto',
#    'Kashipur',
#    'Reinhold',
#    'Hardayal',
#    'Santanum',
#    'Chelmsford',
#    'Kunwar Anand Singh',
#    'Rajendra Babu',
#    'Bapu',
#    'Ramssw',
#    'Hiuen Tsang',
#    'Sven Hedin',
#    'Rabindra Nath Tagore',
#    'Gidwani',
#    'Responsivists',
#    'Dhan Gopal Mukerji',
#    'Neville',
#    'Marco Polo',
#    'Bernard Shaw',
#    'Charlie Andrews',
#    'Winston Churchill',
#    'Lalaji',
#    'Mahendra Pratap',
#    'Shyamaji Krishnavarma',
#    'Lala Lajpat Rai',
#    'Roerich',
#    'Tej',
#    'Madame Cama',
#    'Tnat',
#    'Govermnent',
#    'Tlris',
#    'Ibn Battuta',
#    'Indu',
#    'Pantji',
#    'Moulvi Obeidulla',
#    'Frank Buchman',
#    'Ansari',
#    'Kamala'],
#   '1924': ['Sriyut',
#    'Shaikh',
#    'Arti',
#    'Jawahar',
#    'Jumna',
#    'Tltey',
#    'Tliey',
#    'Swaraj',
#    'Charvaka',
#    'Chamba',
#    'Afi',
#    'Saraswati',
#    'Bapu',
#    'Malaviyaji',
#    'Chitta Ranjan Das',
#    'Mohamed',
#    'Tej',
#    'Maulana Mohamad Ali',
#    'Juhu',
#    'Kfoulvi'],
#   '1925': ['Ranjit S. Pandit'],
#   '1926': ['Lala Lajpat Rai',
#    'Malaviyaji',
#    'Remain Rolland',
#    'Lansbury',
#    'Bidhan Chandra Roy',
#    'Swaraj',
#    'Lady Irwin',
#    'Jivraj Mehta',
#    'John Simon',
#    'John Stuart Mill',
#    'Lalaji',
#    'Ansari',
#    'Hari',
#    'Kamala'],
#   '1928': ['Sardar Vallabhbhai Patel',
#    'Hakimji',
#    'Hakim Ajmal Khan',
#    'Subhas Bose',
#    'Annie Besant',
#    'Bailway',
#    'Bhai',
#    'Govind Ballabh Pant',
#    'Bahadur Sapru',
#    'Kemal Pasha',
#    'Raja Narendra Nath',
#    'Sahab',
#    'Bhagat Singh',
#    'Lalaji',
#    'Lala Lajpat Rai',
#    'Tej',
#    'Govind BaUabh Pant',
#    'John Simon',
#    'Ansari'],
#   '1929': ['Lala Lajpat Rai',
#    'Tej',
#    'Maulana Abul Kalam Azad',
#    'Gokhale',
#    'Sardar Ajit Singh',
#    'Bhagat Singh',
#    'Vithalbhai Patel',
#    'Avas',
#    'Dutt',
#    'Jatindranath Das'],
#   '1931': ['Purushottam Das Tandon',
#    'Mahatma Gandhi',
#    'Srinivasa Sastri',
#    'Thar',
#    'Marariii',
#    'Tasadduq Ahmad Khan Sherwani',
#    'Malcolm Hailey',
#    'Rafi Ahmad Kidwai',
#    'Abdul GhafFar Khan',
#    'Govind Ballabh Pant',
#    'Plindi',
#    'Bahadur Sapru',
#    'Sarojini Naidu',
#    'Venkatesh Narayan Tewary',
#    'Jayakar',
#    'Sri Prakasa',
#    'Purushottan',
#    'Cowasji',
#    'Hijli',
#    'Kamala',
#    'Tej',
#    'Govind BaUabh Pant',
#    'Govermnent',
#    'Pushtu',
#    'Umar Sobani',
#    'Etawah',
#    'Glorney Bolton',
#    'Shiva Prasad Gupta',
#    'Ansari',
#    'Bernard Shaw'],
#   '1937': ['Mahatma Gandhi',
#    'Indira',
#    'Ihere',
#    'Sarojini Naidu',
#    'Khan Abdul Ghaffar Khan',
#    'Kamala'],
#   '1858': ['Vae',
#    'Verrier Elwin',
#    'Swaraj',
#    'Alexander Pope',
#    'Srinivasa Sastri',
#    'Witji',
#    'Rafi Ahmad Kidwai'],
#   '1934': ['Purushottam Das Tandon',
#    'Qiina',
#    'Indira',
#    'Liddell Hart',
#    'Srinivasa Sastri',
#    'Dehra Dun',
#    'Samuel Hoare',
#    'Xalhana',
#    'William Digby',
#    'Rajataranglni',
#    'Karl Marx',
#    'Malcolm Hailey',
#    'Hertzog',
#    'Gokhale',
#    'Rafi Ahmad Kidwai',
#    'Acton',
#    'Swaraj',
#    'Henderson',
#    'Frederick Whyte',
#    'Itse',
#    'Vivekananda',
#    'Sivaswamy',
#    'John Morley',
#    'Santiniketan',
#    'Dadabhai',
#    'Mettemich',
#    'Sarojini Naidu',
#    'Aney',
#    'Giordano Bruno',
#    'Iyer',
#    'Lord Lytton',
#    'William James',
#    'Ramsay MacDonald',
#    'Rabindra Nath Tagore',
#    'Rhan Abdul Ghaiffir Khan',
#    'sachusetts',
#    'Litvinov',
#    'Dutt',
#    'Chengiz Khan',
#    'Inis',
#    'Myslim',
#    'Marshal Haig',
#    'Tej',
#    'Nessim Pasha',
#    'Tnat',
#    'Mirza Ismail',
#    'lias',
#    'Dolfuss',
#    'Britisfr',
#    'Bertrand Russell',
#    'Amaranath',
#    'Wert',
#    'William Currie',
#    'Redshirts',
#    'Kamala'],
#   '1935': ['Sardar Vallabhbhai Patel',
#    'hauer',
#    'Bikaner',
#    'Almora Gaol',
#    'Henry George',
#    'William James',
#    'Ramsay MacDonald',
#    'Thomas Paine',
#    'Bhowali',
#    'Sardar VaUabhbhai Patel',
#    'Sarojini Naidu',
#    'Annie Besant',
#    'Aiyar',
#    'Tinn',
#    'Pope Leo'],
#   '1913': ['Khan Abdul Ghaffiir Khan',
#    'Samuel Hoare',
#    'Ranjit Pandit',
#    'Almora District Gaol',
#    'Bhowali',
#    'Subhas Bose',
#    'Wonderflil',
#    'Kamala']}}

# %%
ent_date_rev = {}
for date in ent_date['places']:
    for ent in ent_date['places'][date]:
        e = ent.lower()
        if e in ent_date_rev:
            ent_date_rev[e].append(date)
        else:
            ent_date_rev[e] = [date]
for date in ent_date['people']:
    for ent in ent_date['people'][date]:
        e = ent.lower()
        if e in ent_date_rev:
            ent_date_rev[e].append(date)
        else:
            ent_date_rev[e] = [date]
ent_date_rev
# Out:
# {'delhi': ['1857',
#   '1930',
#   '1916',
#   '1919',
#   '1939',
#   '1932',
#   '1933',
#   '1924',
#   '1926',
#   '1928',
#   '1929',
#   '1931',
#   '1937',
#   '1934',
#   '1935'],
#  'arabia': ['1857'],
#  'turkey': ['1857', '1919', '1926', '1931', '1934'],
#  'ajmer': ['1857'],
#  'spain': ['1857', '1930', '1934'],
#  'england': ['1857',
#   '1930',
#   '1907',
#   '1916',
#   '1939',
#   '1932',
#   '1933',
#   '1926',
#   '1931',
#   '1858',
#   '1934',
#   '1935'],
#  'kabul': ['1857', '1930', '1926', '1931'],
#  'afghanistan': ['1857', '1920', '1933', '1934', '1935'],
#  'aligarh': ['1857', '1934'],
#  'lucknow': ['1857',
#   '1930',
#   '1916',
#   '1920',
#   '1939',
#   '1921',
#   '1933',
#   '1925',
#   '1926',
#   '1928',
#   '1929',
#   '1931',
#   '1858',
#   '1934'],
#  'egypt': ['1857', '1926', '1934'],
#  'france': ['1857', '1930', '1907', '1916', '1933', '1926', '1934', '1935'],
#  'persia': ['1857', '1930', '1934'],
#  'agra': ['1857', '1920', '1933'],
#  'western': ['1857', '1907', '1933', '1931', '1934', '1935'],
#  'london': ['1857',
#   '1930',
#   '1907',
#   '1916',
#   '1932',
#   '1933',
#   '1924',
#   '1926',
#   '1931',
#   '1934',
#   '1935'],
#  'allahabad': ['1857',
#   '1930',
#   '1907',
#   '1916',
#   '1919',
#   '1920',
#   '1939',
#   '1921',
#   '1932',
#   '1933',
#   '1924',
#   '1925',
#   '1926',
#   '1928',
#   '1931',
#   '1934'],
#  'poona': ['1930', '1907', '1933', '1924', '1931', '1858', '1934'],
#  'japan': ['1930', '1933', '1934', '1935'],
#  'independence': ['1930', '1939', '1921', '1928', '1934'],
#  'raipur': ['1930'],
#  'moscow': ['1930', '1933', '1926'],
#  'cambridge': ['1930', '1907', '1933'],
#  'salt': ['1930'],
#  'new york': ['1930', '1933'],
#  'ahmedabad': ['1930', '1919', '1920', '1924', '1926', '1934', '1935'],
#  'simla': ['1930', '1916', '1920', '1933', '1931', '1934'],
#  'north': ['1930', '1921', '1933', '1924', '1926', '1934'],
#  'australia': ['1930', '1934'],
#  'lahore': ['1930', '1919', '1924', '1928', '1929'],
#  'italy': ['1930', '1907', '1933', '1924', '1926', '1934'],
#  'america': ['1930', '1939', '1921', '1933', '1926', '1928', '1929', '1934'],
#  'zenda': ['1930'],
#  'singapore': ['1930'],
#  'paris': ['1930', '1907', '1933', '1926', '1931', '1858'],
#  'batavia': ['1930'],
#  'union': ['1930', '1939', '1933', '1928', '1931', '1934', '1935'],
#  'russia': ['1930', '1933', '1926', '1928', '1858', '1934'],
#  'gujrat': ['1930', '1920', '1933', '1928', '1858', '1935'],
#  'harrow': ['1930', '1907', '1933'],
#  'peshawar': ['1930'],
#  'karachi': ['1930', '1920', '1931', '1934'],
#  'kars': ['1930'],
#  'madras': ['1930',
#   '1939',
#   '1933',
#   '1926',
#   '1928',
#   '1931',
#   '1858',
#   '1934',
#   '1935'],
#  'germany': ['1930', '1916', '1933', '1926', '1931', '1858', '1934', '1935'],
#  'china': ['1930', '1933', '1926'],
#  'meerut': ['1930', '1939', '1921', '1929'],
#  'tsushima': ['1907'],
#  'ireland': ['1907', '1916', '1933', '1934', '1935'],
#  'geneva': ['1907', '1939', '1933', '1926', '1929'],
#  'dover': ['1907'],
#  'baroda': ['1907', '1935'],
#  'surat': ['1907'],
#  'berlin': ['1907', '1933', '1926'],
#  'norway': ['1907'],
#  'fiji': ['1916', '1920'],
#  'new delhi': ['1916', '1932', '1928', '1931', '1934'],
#  'empire': ['1916', '1921', '1933', '1924', '1931', '1858', '1934'],
#  'south africa': ['1916', '1921', '1931', '1934', '1935'],
#  'amritsar': ['1919', '1921', '1933', '1929'],
#  'fyzabad': ['1920', '1939'],
#  'glasgow': ['1939'],
#  'bray': ['1939'],
#  'akbarpur': ['1939'],
#  'nagpur': ['1939', '1921', '1933', '1929'],
#  'jamshedpur': ['1939'],
#  'dundee': ['1939'],
#  'young': ['1932', '1924'],
#  'canterbury': ['1933', '1931'],
#  'jaito': ['1933'],
#  'istanbul': ['1933'],
#  'ambala': ['1933'],
#  'hampstead': ['1933'],
#  'switzerland': ['1933', '1925', '1926'],
#  'montana': ['1933'],
#  'san francisco': ['1933'],
#  'latvia': ['1933'],
#  'lithuania': ['1933'],
#  'sweden': ['1933'],
#  'patiala': ['1933', '1935'],
#  'almora': ['1933', '1934', '1935', '1913'],
#  'dalhousie': ['1924'],
#  'belgaum': ['1924'],
#  'venice': ['1925', '1926'],
#  'brussels': ['1926'],
#  'marseilles': ['1926'],
#  'mexico': ['1926'],
#  'palestine': ['1926'],
#  'cologne': ['1926'],
#  'colombo': ['1926'],
#  'gorakhpur': ['1929', '1934'],
#  'eden': ['1931'],
#  'chittagong': ['1931'],
#  'paradise': ['1931'],
#  'rome': ['1931', '1934'],
#  'malabar': ['1937'],
#  'travancore': ['1937', '1935'],
#  'cochin': ['1937', '1935'],
#  'jerusalem': ['1937'],
#  'mysore': ['1937', '1934', '1935'],
#  'hyderabad': ['1937', '1935'],
#  'antioch': ['1937'],
#  'whitehall': ['1858', '1934'],
#  'austria': ['1858', '1934'],
#  'howrah': ['1934'],
#  'muzaffarpur': ['1934'],
#  'patna': ['1934'],
#  'cambrai': ['1934'],
#  'rhine': ['1934'],
#  'jamalpur': ['1934'],
#  'byron': ['1934'],
#  'canada': ['1934'],
#  'boston': ['1934'],
#  'calais': ['1934'],
#  'deoli': ['1934'],
#  'liberty': ['1934'],
#  'providence': ['1934'],
#  'cairo': ['1934'],
#  'quetta': ['1935'],
#  'syed ahmad khan': ['1857'],
#  'mudx': ['1857'],
#  'minto': ['1857', '1916'],
#  'madan mohan malaviya': ['1857', '1916'],
#  'rabindranath': ['1857'],
#  'valentine chirol': ['1857', '1921'],
#  'lord lloyd': ['1857'],
#  'agra province': ['1857'],
#  'nand lai nehru': ['1857'],
#  'bahadur sapru': ['1857', '1930', '1916', '1928', '1931'],
#  'kemal pasha': ['1857', '1928'],
#  'farrukhsiar': ['1857'],
#  'malaviyaji': ['1857', '1930', '1924', '1926'],
#  'raj kaul': ['1857'],
#  'ram lila': ['1857'],
#  'tej': ['1857',
#   '1930',
#   '1916',
#   '1933',
#   '1924',
#   '1928',
#   '1929',
#   '1931',
#   '1934'],
#  'muiishiji': ['1857'],
#  'cowley': ['1857'],
#  'amanullah': ['1857', '1920'],
#  'aurungzeb': ['1857'],
#  'munshi mubarak ali': ['1857'],
#  'dhar': ['1857'],
#  'lakshmi narayan nehru': ['1857'],
#  'ansari': ['1857', '1907', '1939', '1933', '1926', '1928', '1931'],
#  'chloe': ['1930'],
#  'sardar vallabhbhai patel': ['1930', '1928', '1935'],
#  'mahatma gandhi': ['1930',
#   '1916',
#   '1919',
#   '1939',
#   '1921',
#   '1932',
#   '1931',
#   '1937'],
#  'bharat bhushan': ['1930'],
#  'jambusar': ['1930'],
#  'indira': ['1930', '1921', '1933', '1937', '1934'],
#  'olrott': ['1930'],
#  'samuel hoare': ['1930', '1932', '1933', '1934', '1913'],
#  'ranjit pandit': ['1930', '1933', '1913'],
#  'blavatsky': ['1930'],
#  'sardar vauabhbhai patel': ['1930', '1935'],
#  'jumna': ['1930', '1920', '1924'],
#  'annie besant': ['1930', '1928', '1935'],
#  'malcolm hailey': ['1930', '1931', '1934'],
#  'gustave dora': ['1930'],
#  'frederick cooper': ['1930'],
#  'gokhale': ['1930', '1907', '1916', '1921', '1929', '1934'],
#  'jairamdas doulatram': ['1930'],
#  'abdul ghaffar khan': ['1930', '1931'],
#  'ibbetson': ['1930'],
#  'swaraj': ['1930',
#   '1939',
#   '1921',
#   '1932',
#   '1933',
#   '1924',
#   '1926',
#   '1858',
#   '1934'],
#  'lewis carroll': ['1930'],
#  'govind ballabh pant': ['1930', '1928', '1931'],
#  'apollonius': ['1930'],
#  'don quixote': ['1930'],
#  'lewis e. lawes': ['1930'],
#  'lafeadio hearn': ['1930'],
#  'eleven points': ['1930'],
#  'irwm': ['1930', '1932'],
#  'sarojini naidu': ['1930', '1916', '1921', '1931', '1937', '1934', '1935'],
#  'garhwalis': ['1930'],
#  'chandrashekhar azad': ['1930'],
#  'syed mahmucl': ['1930'],
#  'madeleine slade': ['1930'],
#  'jayakar': ['1930', '1931'],
#  'queen victoria': ['1930'],
#  'narmada prasad': ['1930', '1932'],
#  'ramsay macdonald': ['1930', '1934', '1935'],
#  'chauri': ['1930', '1932'],
#  'khudai khidmatgar': ['1930'],
#  'iwer': ['1930'],
#  'motilal': ['1930', '1921'],
#  'ranjit s. pandit': ['1930', '1925'],
#  'thomas moore': ['1930'],
#  'bhagat singh': ['1930', '1928', '1929'],
#  'marshal foch': ['1930'],
#  'srinivas sastri': ['1930', '1916'],
#  'kamala': ['1930', '1920', '1933', '1926', '1931', '1937', '1934', '1913'],
#  'saprii': ['1930'],
#  'qiauri chaura': ['1930'],
#  'khan abdul ghaffar khan': ['1930', '1937'],
#  'anand bhawan': ['1930', '1921'],
#  'syed mahmud': ['1930', '1907'],
#  'maulana abul kalam azad': ['1930', '1929'],
#  'ganeshji': ['1930'],
#  'abdul ghaffor khan': ['1930'],
#  'miraben': ['1930'],
#  'bryce': ['1930'],
#  'keith': ['1930'],
#  'maulana mohamad ali': ['1930', '1924'],
#  'jhanda': ['1930'],
#  'redshirts': ['1930', '1934'],
#  'kirkee': ['1930'],
#  'deshbandhu das': ['1930', '1920', '1921'],
#  'latham': ['1907'],
#  'khwaja': ['1907'],
#  'edwin montagu': ['1907', '1916'],
#  'nevinson': ['1907'],
#  'paramjit singh': ['1907'],
#  'walter pater': ['1907', '1921'],
#  'farman': ['1907'],
#  'majlis': ['1907'],
#  'sahab': ['1907', '1928'],
#  'shyamji': ['1907'],
#  'bepin pal': ['1907'],
#  'lalaji': ['1907', '1921', '1933', '1926', '1928'],
#  'lala lajpat rai': ['1907', '1921', '1933', '1926', '1928', '1929'],
#  'dayal': ['1907'],
#  'inis': ['1907', '1934'],
#  'zeppdin': ['1907'],
#  'otto weininger': ['1907'],
#  'bernard shaw': ['1907', '1933', '1931'],
#  'manasarovar': ['1916'],
#  'srinivasa sastri': ['1916', '1921', '1933', '1931', '1858', '1934'],
#  'lokamanya tilak': ['1916', '1919', '1921'],
#  'basu': ['1916'],
#  'matayan': ['1916'],
#  'chelmsford': ['1916', '1919', '1920', '1933'],
#  'bhupendra nath basy': ['1916'],
#  'forster': ['1916'],
#  'khaparde': ['1916'],
#  'bertrand russell': ['1916', '1934'],
#  'amaranath': ['1916', '1934'],
#  'shaukat ali': ['1919'],
#  'swami shraddhananda': ['1919'],
#  'sardar vallabbhai patel': ['1920'],
#  'richard b. gregg': ['1920'],
#  'hindt ramayana': ['1920'],
#  'wolseley': ['1920'],
#  'dehra dun': ['1920', '1933', '1934'],
#  'richard garnett': ['1920'],
#  'ramacnandra': ['1920'],
#  'wotton': ['1920'],
#  'vithalbhai patel': ['1920', '1929'],
#  'reinhold': ['1920', '1933'],
#  'baba ramachandra': ['1920'],
#  'grimwood': ['1920'],
#  'ayodhya': ['1920'],
#  'joshi': ['1939'],
#  'purushottam das tandon': ['1921', '1931', '1934'],
#  'balkrishna sharma': ['1921'],
#  'rama raj': ['1921'],
#  'devadas gandhi': ['1921'],
#  'khan bahadur': ['1921'],
#  'santiniketan': ['1921', '1934'],
#  'maulanas': ['1921'],
#  'lala lajpatrai': ['1921'],
#  'mahadev desai': ['1921'],
#  'rabindra nath tagore': ['1921', '1933', '1934'],
#  'swarup': ['1921'],
#  'george joseph': ['1921'],
#  'seeley': ['1921'],
#  'bernard aluvihare': ['1932'],
#  'matthew arnold': ['1932'],
#  'mohanlal nehru': ['1932'],
#  'banjit pandit': ['1932'],
#  'willingdon': ['1932'],
#  'moonje': ['1933'],
#  'voltairej': ['1933'],
#  'rajagopalachariar': ['1933'],
#  'barkatulla': ['1933'],
#  'ernst toller': ['1933'],
#  'samamim': ['1933'],
#  'john dewey': ['1933'],
#  'sarup': ['1933'],
#  'subhas bose': ['1933', '1928', '1913'],
#  'ritssia': ['1933'],
#  'verrier elwin': ['1933', '1858'],
#  'champakraman pillai': ['1933'],
#  'remain rolland': ['1933', '1926'],
#  'roger baldwin': ['1933'],
#  'kapil': ['1933'],
#  'chatto': ['1933'],
#  'kashipur': ['1933'],
#  'hardayal': ['1933'],
#  'santanum': ['1933'],
#  'kunwar anand singh': ['1933'],
#  'rajendra babu': ['1933'],
#  'bapu': ['1933', '1924'],
#  'ramssw': ['1933'],
#  'hiuen tsang': ['1933'],
#  'sven hedin': ['1933'],
#  'gidwani': ['1933'],
#  'responsivists': ['1933'],
#  'dhan gopal mukerji': ['1933'],
#  'neville': ['1933'],
#  'marco polo': ['1933'],
#  'charlie andrews': ['1933'],
#  'winston churchill': ['1933'],
#  'mahendra pratap': ['1933'],
#  'shyamaji krishnavarma': ['1933'],
#  'roerich': ['1933'],
#  'madame cama': ['1933'],
#  'tnat': ['1933', '1934'],
#  'govermnent': ['1933', '1931'],
#  'tlris': ['1933'],
#  'ibn battuta': ['1933'],
#  'indu': ['1933'],
#  'pantji': ['1933'],
#  'moulvi obeidulla': ['1933'],
#  'frank buchman': ['1933'],
#  'sriyut': ['1924'],
#  'shaikh': ['1924'],
#  'arti': ['1924'],
#  'jawahar': ['1924'],
#  'tltey': ['1924'],
#  'tliey': ['1924'],
#  'charvaka': ['1924'],
#  'chamba': ['1924'],
#  'afi': ['1924'],
#  'saraswati': ['1924'],
#  'chitta ranjan das': ['1924'],
#  'mohamed': ['1924'],
#  'juhu': ['1924'],
#  'kfoulvi': ['1924'],
#  'lansbury': ['1926'],
#  'bidhan chandra roy': ['1926'],
#  'lady irwin': ['1926'],
#  'jivraj mehta': ['1926'],
#  'john simon': ['1926', '1928'],
#  'john stuart mill': ['1926'],
#  'hari': ['1926'],
#  'hakimji': ['1928'],
#  'hakim ajmal khan': ['1928'],
#  'bailway': ['1928'],
#  'bhai': ['1928'],
#  'raja narendra nath': ['1928'],
#  'govind bauabh pant': ['1928', '1931'],
#  'sardar ajit singh': ['1929'],
#  'avas': ['1929'],
#  'dutt': ['1929', '1934'],
#  'jatindranath das': ['1929'],
#  'thar': ['1931'],
#  'marariii': ['1931'],
#  'tasadduq ahmad khan sherwani': ['1931'],
#  'rafi ahmad kidwai': ['1931', '1858', '1934'],
#  'plindi': ['1931'],
#  'venkatesh narayan tewary': ['1931'],
#  'sri prakasa': ['1931'],
#  'purushottan': ['1931'],
#  'cowasji': ['1931'],
#  'hijli': ['1931'],
#  'pushtu': ['1931'],
#  'umar sobani': ['1931'],
#  'etawah': ['1931'],
#  'glorney bolton': ['1931'],
#  'shiva prasad gupta': ['1931'],
#  'ihere': ['1937'],
#  'vae': ['1858'],
#  'alexander pope': ['1858'],
#  'witji': ['1858'],
#  'qiina': ['1934'],
#  'liddell hart': ['1934'],
#  'xalhana': ['1934'],
#  'william digby': ['1934'],
#  'rajataranglni': ['1934'],
#  'karl marx': ['1934'],
#  'hertzog': ['1934'],
#  'acton': ['1934'],
#  'henderson': ['1934'],
#  'frederick whyte': ['1934'],
#  'itse': ['1934'],
#  'vivekananda': ['1934'],
#  'sivaswamy': ['1934'],
#  'john morley': ['1934'],
#  'dadabhai': ['1934'],
#  'mettemich': ['1934'],
#  'aney': ['1934'],
#  'giordano bruno': ['1934'],
#  'iyer': ['1934'],
#  'lord lytton': ['1934'],
#  'william james': ['1934', '1935'],
#  'rhan abdul ghaiffir khan': ['1934'],
#  'sachusetts': ['1934'],
#  'litvinov': ['1934'],
#  'chengiz khan': ['1934'],
#  'myslim': ['1934'],
#  'marshal haig': ['1934'],
#  'nessim pasha': ['1934'],
#  'mirza ismail': ['1934'],
#  'lias': ['1934'],
#  'dolfuss': ['1934'],
#  'britisfr': ['1934'],
#  'wert': ['1934'],
#  'william currie': ['1934'],
#  'hauer': ['1935'],
#  'bikaner': ['1935'],
#  'almora gaol': ['1935'],
#  'henry george': ['1935'],
#  'thomas paine': ['1935'],
#  'bhowali': ['1935', '1913'],
#  'aiyar': ['1935'],
#  'tinn': ['1935'],
#  'pope leo': ['1935'],
#  'khan abdul ghaffiir khan': ['1913'],
#  'almora district gaol': ['1913'],
#  'wonderflil': ['1913']}

# %%
json.dump(ent_date, open('json_files/%s/date_to_entity_dict.json' % book,'w'),indent = 4)
json.dump(ent_date_rev, open('json_files/%s/entity_to_date_dict.json' % book,'w'),indent = 4)

# %%
f = open('Jawaharlal_Nehru_Autobiography/chapters.txt','r')
d = {}
# chapters = [24,29,23,47,44]
chapters = [68]
part = 1
for ch in chapters:
    d[part] = {}
    for i in range(ch):
        l = f.readline().split(':')[1].split(" ",1)[1].strip()
        d[part][i+1]=l
    part+=1
    
f.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-ae880848e0fb> in <module>
#       7     d[part] = {}
#       8     for i in range(ch):
# ----> 9         l = f.readline().split(':')[1].split(" ",1)[1].strip()
#      10         d[part][i+1]=l
#      11     part+=1
#
# IndexError: list index out of range

# %%
d

# %%
json.dump(d, open('json_files/%s/chapter_names.json' % book,'w'),indent = 4)

# %%
with open('json_files/%s/year_mode_dict_cassigned.json' %book) as data_file:
    chap_years = json.load(data_file)
year_chap = {}
for part in chap_years.keys():
    for ch in chap_years[part].keys():
        t = (part,ch,d[int(part)][int(ch)])
        try:
            year_chap[chap_years[part][ch]].append(t)
        except:
            year_chap[chap_years[part][ch]]=[t]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fc7c978ca7c7> in <module>
#       4 for part in chap_years.keys():
#       5     for ch in chap_years[part].keys():
# ----> 6         t = (part,ch,d[int(part)][int(ch)])
#       7         try:
#       8             year_chap[chap_years[part][ch]].append(t)
#
# NameError: name 'd' is not defined

# %%
year_chap
# Out:
# {}

# %%
json.dump(year_chap, open('json_files/%s/year_chapter_chaptername_dict.json' % book,'w'),indent = 4)

# %%
notation_int_map = {}
location_list_map = {}
# 0 = PERSON 1 = PLACE
notation_int_map['PERSON'] = 0
notation_int_map['GPE'] = 1
dir_path = './%s/part'% book
with open('json_files/' + str(book) + '/final_chapter_entity_map_tfidf.json') as data_file:
    entity_map = json.load(data_file)
mentions = {}
for part in range(1,Parts+1):
    
    x = 1
    no_of_chapters = len(fnmatch.filter(os.listdir(dir_path + str(part) + '/'), '*.txt'))
    print('no.of_chapters:' + str(no_of_chapters))
    print('part:' + str(part))
    while x <= no_of_chapters:
        part = str(part)
        
        target_x = no_of_chapters+1
        for i in range(x,target_x):
            with open(dir_path + str(part) + '/chapter'+ str(i) + '.txt', 'r', encoding='utf-8') as content_file:
                content = content_file.read()
            i = str(i)
            # content = unicode(content, "utf-8")
            
            for sent in nltk.sent_tokenize(content):
                for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
                    

                    entity = ' '.join(c[0] for c in chunk)
                    if entity in entity_map[str(part)][str(i)]:
                        if entity in mentions:
                            if i in mentions[entity][part]:
                                mentions[entity][part][i].append(sent)
                            else:
                                mentions[entity][part][i]=[sent]
                        else:
                            mentions[entity]={'1':{},'2':{},'3':{},'4':{},'5':{}}
                            mentions[entity][part]={i:[sent]}
        
        x = target_x
# Out:
# no.of_chapters:6
# part:1

# %%
mentions['Ahmedabad']
# Out:
# {'1': {'7': ['First came the jute\nindustry of Bengal, with its nerve centre at Dundee in Scotland; much later\ncotton mills grew up in Ahmedabad and Bombay, largely with Indian capital and\nunder Indian ownership; then came mining.',
#    'Ahmedabad,\nthe new centre of the textile industry, had been a famous manufacturing and\ntrade centre during the Mughal period and even earlier, exporting its products to\nforeign countries.',
#    'The big merchants of Ahmedabad had their own ships for this\nseaborne trade to Africa and the Persian Gulf.'],
#   '8': ['Industry developed during the war and produced enormous dividends—100 to\n200 per cent—from the jute mills of Bengal and the cotton mills of Bombay,\nAhmedabad, and elsewhere.',
#    'The largest\nand best-organized trade union—that of the Ahmedabad textile industry—was\nstarted by Congressmen and worked in close co-operation with them.'],
#   '10': ['In the great textile centre of Ahmedabad also\nthere was a sudden and complete stoppage of work in all the numerous factories\nwithout any special cad from the trade union.1 This general strike in Ahmedabad\ncontinued peacefully for over three months in spite of all attempts to break it.',
#    'In the great textile centre of Ahmedabad also\nthere was a sudden and complete stoppage of work in all the numerous factories\nwithout any special cad from the trade union.1 This general strike in Ahmedabad\ncontinued peacefully for over three months in spite of all attempts to break it.']},
#  '2': {},
#  '3': {},
#  '4': {},
#  '5': {}}

# %%
json.dump(mentions, open('json_files/%s/mentions.json' % book,'w'),indent = 4)
